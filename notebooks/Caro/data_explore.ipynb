# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../../raw_data/bitstampUSD.csv')

# %%
data.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
data.shape
# Out:
# (4727777, 8)

# %%
data.isnull().sum()
# Out:
# Timestamp                  0
# Open                 1243472
# High                 1243472
# Low                  1243472
# Close                1243472
# Volume_(BTC)         1243472
# Volume_(Currency)    1243472
# Weighted_Price       1243472
# dtype: int64

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'], unit='s', origin='unix')

# %%
data.head()
# Out:
#             Timestamp  Open  High   Low  Close  Volume_(BTC)  \
# 0 2011-12-31 07:52:00  4.39  4.39  4.39   4.39      0.455581
# 1 2011-12-31 07:53:00   NaN   NaN   NaN    NaN           NaN
# 2 2011-12-31 07:54:00   NaN   NaN   NaN    NaN           NaN
# 3 2011-12-31 07:55:00   NaN   NaN   NaN    NaN           NaN
# 4 2011-12-31 07:56:00   NaN   NaN   NaN    NaN           NaN
#
#    Volume_(Currency)  Weighted_Price
# 0                2.0            4.39
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN             NaN
# 4                NaN             NaN

# %%
data.loc['2014-01-01':'2015-01-01']
# Out:
#                   Timestamp    Open    High     Low   Close  Volume_(BTC)  \
# 2014000 2015-11-03 10:24:00  385.55  385.55  383.29  383.83    134.243263
# 2014001 2015-11-03 10:25:00  384.00  384.00  383.30  383.30     33.468344
# 2014002 2015-11-03 10:26:00  383.82  384.00  383.00  383.97     26.907101
# 2014003 2015-11-03 10:27:00  383.97  383.99  381.28  381.65    142.526607
# 2014004 2015-11-03 10:28:00  381.66  381.91  379.11  379.11     69.300111
# ...                     ...     ...     ...     ...     ...           ...
# 2014995 2015-11-04 02:59:00  431.28  434.53  431.28  434.02    261.545753
# 2014996 2015-11-04 03:00:00  434.03  434.56  431.31  431.92     25.099495
# 2014997 2015-11-04 03:01:00  431.50  432.17  431.32  432.17    106.610630
# 2014998 2015-11-04 03:02:00  432.17  432.17  431.36  431.50      4.735330
# 2014999 2015-11-04 03:03:00  431.51  434.84  431.51  433.96     50.502670
#
#          Volume_(Currency)  Weighted_Price
# ...

# %%
not_data = data[data['Open'].isna()]
not_data
# Out:
#                   Timestamp  Open  High  Low  Close  Volume_(BTC)  \
# 1       2011-12-31 07:53:00   NaN   NaN  NaN    NaN           NaN
# 2       2011-12-31 07:54:00   NaN   NaN  NaN    NaN           NaN
# 3       2011-12-31 07:55:00   NaN   NaN  NaN    NaN           NaN
# 4       2011-12-31 07:56:00   NaN   NaN  NaN    NaN           NaN
# 5       2011-12-31 07:57:00   NaN   NaN  NaN    NaN           NaN
# ...                     ...   ...   ...  ...    ...           ...
# 4712395 2020-12-20 07:39:00   NaN   NaN  NaN    NaN           NaN
# 4712953 2020-12-20 16:57:00   NaN   NaN  NaN    NaN           NaN
# 4720840 2020-12-26 04:24:00   NaN   NaN  NaN    NaN           NaN
# 4720920 2020-12-26 05:44:00   NaN   NaN  NaN    NaN           NaN
# 4721385 2020-12-26 13:29:00   NaN   NaN  NaN    NaN           NaN
#
#          Volume_(Currency)  Weighted_Price
# 1                      NaN             NaN
# 2                      NaN             NaN
# ...

# %%
sns.heatmap(data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#             Timestamp  Open  High   Low  Close  Volume_(BTC)  \
# 0 2011-12-31 07:52:00  4.39  4.39  4.39   4.39      0.455581
# 1 2011-12-31 07:53:00   NaN   NaN   NaN    NaN           NaN
# 2 2011-12-31 07:54:00   NaN   NaN   NaN    NaN           NaN
# 3 2011-12-31 07:55:00   NaN   NaN   NaN    NaN           NaN
# 4 2011-12-31 07:56:00   NaN   NaN   NaN    NaN           NaN
#
#    Volume_(Currency)  Weighted_Price
# 0                2.0            4.39
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN             NaN
# 4                NaN             NaN

# %%
# data = data[2701596:3000000]
data_sample = data[4727500:]
# data_sample['Open'] = data_sample['Open'].apply(lambda x: str(x).replace('nan', ''))
# data_sample['Open'] = data_sample['Open'].astype(float)

# %%
plt.plot_date(data_sample['Timestamp'], data_sample['Open'], markersize=2, markeredgewidth=0, color='r')
plt.show()

# %%
data_sample.head(20)
# Out:
#              Timestamp  Open  High   Low  Close  Volume_(BTC)  \
# 0  2011-12-31 07:52:00  4.39  4.39  4.39   4.39      0.455581
# 1  2011-12-31 07:53:00   NaN   NaN   NaN    NaN           NaN
# 2  2011-12-31 07:54:00   NaN   NaN   NaN    NaN           NaN
# 3  2011-12-31 07:55:00   NaN   NaN   NaN    NaN           NaN
# 4  2011-12-31 07:56:00   NaN   NaN   NaN    NaN           NaN
# 5  2011-12-31 07:57:00   NaN   NaN   NaN    NaN           NaN
# 6  2011-12-31 07:58:00   NaN   NaN   NaN    NaN           NaN
# 7  2011-12-31 07:59:00   NaN   NaN   NaN    NaN           NaN
# 8  2011-12-31 08:00:00   NaN   NaN   NaN    NaN           NaN
# 9  2011-12-31 08:01:00   NaN   NaN   NaN    NaN           NaN
# 10 2011-12-31 08:02:00   NaN   NaN   NaN    NaN           NaN
# 11 2011-12-31 08:03:00   NaN   NaN   NaN    NaN           NaN
# 12 2011-12-31 08:04:00   NaN   NaN   NaN    NaN           NaN
# 13 2011-12-31 08:05:00   NaN   NaN   NaN    NaN           NaN
# ...

# %%
plt.figure(figsize=(22,5))
sns.pointplot(data=data_sample, x='Timestamp', y='Open')
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Open'>
